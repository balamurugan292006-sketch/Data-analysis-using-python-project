# %% [markdown]
# <a href="https://colab.research.google.com/github/balamurugan292006-sketch/Data-analysis-using-python-project/blob/main/Bala.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {

'emp_nm': ['maha', 'Lakshmi'],

'emp_sal': [300,500],

}

df = pd.DataFrame(data)

df.rename(columns={

'emp_nm': 'Employee Name',

'emp_sal':'Employee Salary'

}, inplace = True)

print(df)
