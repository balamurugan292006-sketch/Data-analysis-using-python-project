# %% [markdown]
# <a href="https://colab.research.google.com/github/balamurugan292006-sketch/Data-analysis-using-python-project/blob/main/pythonproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]

# %%
import pandas as pd

data = {
        "Name" : ["Ihshan","Ravi","Siva"],
        "Sales": [500,1500,2500]
}
df = pd.DataFrame(data)
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
import pandas as pd

data = {
     'emp_nm' :['Bala','Siva'],
     'emp_sal':[300,500],
}
df = pd.DataFrame(data)
df.rename(columns={
    'emp_nm' : 'Employee Name',
    'emp_sal': 'Employee Salary'
    }, inplace = True)
print(df)
# Out:
#   Employee Name  Employee Salary
# 0          Bala              300
# 1          Siva              500

# %%
import pandas as pd

data = {
    "Region":["South","North","East","West","South","North"],
    "Products":["Laptop","Mobile","Tablet","Laptop","Mobile","Tablet"],
    "Sales":[6000,7000,8000,9000,10000,11000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Region Products  Sales
# 0  South   Laptop   6000
# 1  North   Mobile   7000
# 2   East   Tablet   8000
# 3   West   Laptop   9000
# 4  South   Mobile  10000
# 5  North   Tablet  11000

# %%
import matplotlib.pyplot as plt
months = ["Jan","Feb","Mar","Apr","May"]
sales = [10000,12000,15000,13000,18000]
plt.plot(months,sales)
plt.title("Monthly sales")
plt.xlabel("Months")
plt.ylabel("Sales Amount")
plt.show()

# %%
import matplotlib.pyplot as plt
students = ["A","B","C","D"]
marks = [89,98,75,95]
plt.bar(students,marks)
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
import pandas as pd

data = pd.Series([10, 20, 30])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd

data = pd.Series(
    [100, 200, 700],
    index=["ALARM", "RADAR", "CHARGER"]
)

print(data)
# Out:
# ALARM      100
# RADAR      200
# CHARGER    700
# dtype: int64

# %%
import pandas as pd

data = pd.Series([10, 20, 30])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# List of expenses
Expenses = [100, 250, 300, 150]

# Calculate total expenses
Total = sum(Expenses)

# Display the results
print("Expenses:", Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [100, 250, 300, 150]
# Total Expenses: 800

# %%
def greet():
    print("Hi Intership Students")

greet()
# Out:
# Hi Intership Students

# %%
file = open("sample.txt", "w")

file.write("Hello World")
file.write("\nWelcome to Python")

file.close()

file = open("sample.txt", "r")

print(file.read())

file.close()
# Out:
# Hello World
# Welcome to Python
